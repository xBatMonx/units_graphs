# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from pandas import read_csv
from pandas import DataFrame
from pandas import concat

# %%
units = read_csv('a_sys_05.csv')

# %%
for i in range(len(units)):
    if units['Unit Impedance'][i] == 'Out of Range':
        units['Unit Impedance'][i] = 10
# Out:
# C:\Users\weymo\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
unit = 34
string = 2
plt.plot([units['Unit Impedance'][i] for i in range(len(units)) if units['Unit'][i] == unit and units['String'][i] == string])
plt.show()

# %%
unit = 32
string = 2
plt.plot([units['Unit Impedance'][i] for i in range(len(units)) if units['Unit'][i] == unit and units['String'][i] == string])
plt.show()

# %%
unit = 22
string = 4
plt.plot([units['Unit Impedance'][i] for i in range(len(units)) if units['Unit'][i] == unit and units['String'][i] == string])
plt.show()

# %%
num_units = 40
num_strings = 4

for k in range(1, num_strings+1):
    for j in range(1, num_units+1):
        print('unit', j)
        print('string', k)
        plt.plot([units['Unit Impedance'][i] for i in range(len(units)) if units['Unit'][i] == j and units['String'][i] == k])
        plt.show()
# Out:
# unit 1
# string 1
# unit 2
# string 1
# unit 3
# string 1
# unit 4
# string 1
# unit 5
# string 1
# unit 6
# string 1
# unit 7
# string 1
# unit 8
# string 1
# unit 9
# string 1
# unit 10
# string 1
# unit 11
# string 1
# unit 12
# string 1
# unit 13
# string 1
# unit 14
# string 1
# unit 15
# string 1
# unit 16
# string 1
# unit 17
# string 1
# unit 18
# string 1
# unit 19
# string 1
# unit 20
# string 1
# unit 21
# string 1
# unit 22
# string 1
# unit 23
# string 1
# unit 24
# string 1
# unit 25
# string 1
# unit 26
# string 1
# unit 27
# string 1
# unit 28
# string 1
# unit 29
# string 1
# unit 30
# string 1
# unit 31
# string 1
# unit 32
# string 1
# unit 33
# string 1
# unit 34
# string 1
# unit 35
# string 1
# unit 36
# string 1
# unit 37
# string 1
# unit 38
# string 1
# unit 39
# string 1
# unit 40
# string 1
# unit 1
# string 2
# unit 2
# string 2
# unit 3
# string 2
# unit 4
# string 2
# unit 5
# string 2
# unit 6
# string 2
# unit 7
# string 2
# unit 8
# string 2
# unit 9
# ...
