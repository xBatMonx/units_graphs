# %%
import matplotlib.pyplot as plt
from pandas import read_csv

# %%
units = read_csv('sys_3.csv')
# Out:
# C:\Users\weymo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in range(len(units)):
    if units['Unit Impedance'][i] == 'Out of Range':
        units['Unit Impedance'][i] = 10
    if units['Unit Voltage'][i] == 'Out of Range':
        units['Unit Voltage'][i] = 20

# %%
#Was there a change out after week 400 - 425
#Impedance looks continuous but other units show discontinuity
plot_imp_volt(units, 34, 1)

# %%
#Unit decreases impedance after after starting high - Normal?
plot_imp_volt(units, 5, 3)

# %%
num_units = 40
num_strings = 3

for k in range(1, num_strings+1):
    for j in range(1, num_units+1):
        print('unit', j)
        print('string', k)
        plot_imp_volt(units, j, k)
# Out:
# unit 1
# string 1
# unit 2
# string 1
# unit 3
# string 1
# unit 4
# string 1
# unit 5
# string 1
# unit 6
# string 1
# unit 7
# string 1
# unit 8
# string 1
# unit 9
# string 1
# unit 10
# string 1
# unit 11
# string 1
# unit 12
# string 1
# unit 13
# string 1
# unit 14
# string 1
# unit 15
# string 1
# unit 16
# string 1
# unit 17
# string 1
# unit 18
# string 1
# unit 19
# string 1
# unit 20
# string 1
# unit 21
# string 1
# unit 22
# string 1
# unit 23
# string 1
# unit 24
# string 1
# unit 25
# string 1
# unit 26
# string 1
# unit 27
# string 1
# unit 28
# string 1
# unit 29
# string 1
# unit 30
# string 1
# unit 31
# string 1
# unit 32
# string 1
# unit 33
# string 1
# unit 34
# string 1
# unit 35
# string 1
# unit 36
# string 1
# unit 37
# string 1
# unit 38
# string 1
# unit 39
# string 1
# unit 40
# string 1
# unit 1
# string 2
# unit 2
# string 2
# unit 3
# string 2
# unit 4
# string 2
# unit 5
# string 2
# unit 6
# string 2
# unit 7
# string 2
# unit 8
# string 2
# unit 9
# string 2
# unit 10
# string 2
# unit 11
# string 2
# unit 12
# string 2
# unit 13
# string 2
# unit 14
# string 2
# unit 15
# string 2
# unit 16
# string 2
# unit 17
# string 2
# unit 18
# string 2
# unit 19
# string 2
# unit 20
# string 2
# unit 21
# string 2
# unit 22
# string 2
# unit 23
# string 2
# unit 24
# string 2
# unit 25
# string 2
# unit 26
# string 2
# unit 27
# string 2
# unit 28
# string 2
# unit 29
# string 2
# unit 30
# string 2
# unit 31
# string 2
# unit 32
# string 2
# unit 33
# string 2
# unit 34
# string 2
# unit 35
# string 2
# unit 36
# string 2
# unit 37
# string 2
# unit 38
# string 2
# unit 39
# string 2
# unit 40
# string 2
# unit 1
# string 3
# unit 2
# string 3
# unit 3
# string 3
# unit 4
# string 3
# unit 5
# string 3
# unit 6
# string 3
# unit 7
# string 3
# unit 8
# string 3
# unit 9
# string 3
# unit 10
# string 3
# unit 11
# string 3
# unit 12
# string 3
# unit 13
# string 3
# unit 14
# string 3
# unit 15
# string 3
# unit 16
# string 3
# unit 17
# string 3
# unit 18
# string 3
# unit 19
# string 3
# unit 20
# string 3
# unit 21
# string 3
# unit 22
# string 3
# unit 23
# string 3
# unit 24
# string 3
# unit 25
# string 3
# unit 26
# string 3
# unit 27
# string 3
# unit 28
# string 3
# unit 29
# string 3
# unit 30
# string 3
# unit 31
# string 3
# unit 32
# string 3
# unit 33
# string 3
# unit 34
# string 3
# unit 35
# string 3
# unit 36
# string 3
# unit 37
# string 3
# unit 38
# string 3
# unit 39
# string 3
# unit 40
# string 3

# %%
def plot_imp_volt(units, unit, string):
    fig, ax1 = plt.subplots()
    ax1.plot([units['Unit Impedance'][i] for i in range(len(units)) if units['Unit'][i] == unit and units['String'][i] == string], 'b-')
    ax1.set_xlabel('time (weeks)')
    # Make the y-axis label, ticks and tick labels match the line color.
    ax1.set_ylabel('impedance', color='b')
    ax1.tick_params('y', colors='b')
    ax2 = ax1.twinx()
    ax2.plot([units['Unit Voltage'][i] for i in range(len(units)) if units['Unit'][i] == unit and units['String'][i] == string], 'r.')
    ax2.set_ylabel('voltage', color='r')
    ax2.tick_params('y', colors='r')
    fig.tight_layout()
    plt.show()
